# %% [markdown]
# ## Coles Supermarkets
# ### We choose 5 categories and further two subcategories from each category.
# #### 1)-Dairy, Eggs & Fridge
#         * Milk
#         * Yougurt
#
# #### 2)-Fruit & Vegetables
#         * Fresh Fruits
#         * Fresh vegetables
#
# #### 3)-Pantry
#         * Cofee
#         * Canned Food (Fish & Sea-Food)
#         * Olive oils
#         * Chocolate Blocks
#
# #### 4)-Baby
#        * Baby Food
#
# #### 5)-Health
#     * Vitamins and Supplements

# %%
# import Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialise PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.supermarket_db
collection = db.colesitems

# %%
# Milk URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/dairy-eggs-fridge/milk?sortBy=priceAscending'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
#   #  Milk

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
Milk_results = soup.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in Milk_results:
    # Error handling
    try:
        # Identify and return title of product listing
#        
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__value').text

        # Run only if titles, prices per 1 Liter, 
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Coles Full Cream Milk | 600mL
# $1.30
# -------------
# Coles Lite Milk Bottle | 1L
# $1.60
# -------------
# Coles Skim Milk Bottle | 1L
# $1.60
# -------------
# Coles Dairy Full Cream Milk | 1L
# $1.60
# -------------
# Coles Good Yums Strawberry Flavoured Milk | 250mL
# $1.95
# -------------
# Coles Good Yums Chocolate Flavoured Milk | 250mL
# $1.95
# -------------
# Vitasoy Whole Chocolate Almond Milk | 330mL
# $2.00
# -------------
# Vitasoy Iced Coffee Double Espresso | 330mL
# $2.00
# -------------
# Pauls Bluey Chocolate Flavoured Milk | 250mL
# $2.00
# -------------
# Pauls Bluey Strawberry Flavoured Milk | 250mL
# $2.00
# -------------
# Pauls Bluey Banana Flavoured Milk | 250mL
# $2.00
# -------------
# Bubble Milk Tea Original With Tapioca Pearls | 350mL
# $2.00
# -------------
# Dairy Farmers Full Cream Milk Carton | 600mL
# $2.00
# -------------
# Vitasoy Oat Latte | 330mL
# $2.00
# -------------
# Coles Organic Unsweetened Coconut Milk | 1L
# $2.25
# ...

# %% [markdown]
# # Yougurt

# %%
# URL of page (contains yougurt info) to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/dairy-eggs-fridge/dairy/yoghurt?sortBy=priceAscending'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup1 = BeautifulSoup(response.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
Yougurt_results = soup1.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in Yougurt_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text

       # Run only if titles, prices per 1 Liter, 
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Coles Squeezie Strawberry Yoghurt | 70g
# $1.07 per 100g
# -------------
# Coles Squeezie Banana Yoghurt | 70g
# $1.07 per 100g
# -------------
# Coles Squeezie Yoghurt Vanilla | 70g
# $1.07 per 100g
# -------------
# Coles Squeezie Yoghurt Blueberry | 70g
# $1.07 per 100g
# -------------
# Yoplait Petit Miam Vanilla Yoghurt Pouch | 70g
# $1.14 per 100g | Was $1.00
# -------------
# Yoplait Petit Miam Mango Yoghurt Pouch | 70g
# $1.14 per 100g | Was $1.00
# -------------
# Yoplait Petit Miam Yoghurt Vanilla Apple | 70g
# $1.14 per 100g | Was $1.00
# -------------
# Yoplait Petit Miam Strawberry & Banana | 70g
# $1.14 per 100g | Was $1.00
# -------------
# Yoplait Petit Miam Squeezie Fruit Salad Yoghurt Pouch | 70g
# $1.14 per 100g | Was $1.00
# -------------
# Yoplait Petit Miam Squeezie Strawberry Yoghurt Pouch | 70g
# $1.14 per 100g | Was $1.00
# -------------
# Yoplait Petit Miam Squeezie Banana Yoghurt Pouch | 70g
# $1.14 per 100g | Was $1.00
# -------------
# ...

# %% [markdown]
# # Vegetables

# %%
veggie_url = 'https://www.coles.com.au/browse/fruit-vegetables/vegetables?sortBy=priceAscending'

# Retrieve page with the requests module
veggie_response = requests.get(veggie_url)
# Create BeautifulSoup object; parse with 'lxml'
soup2 = BeautifulSoup(veggie_response.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
Veggie_results = soup2.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in Veggie_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Coles Greenhouse Truss Tomatoes | approx. 140g each
# $2.80 per 1kg
# -------------
# Coles Green Zucchini | Approx. 260g each
# $4.90 per 1kg
# -------------
# Coles Sweet Corn | 1 each
# $1.30 per 1ea
# -------------
# Coles Wrapped Butternut Pumpkin | approx. 700g each
# $2.50 per 1kg
# -------------
# Coles Baby Carrots Prepacked | 500g
# $3.60 per 1kg
# -------------
# Coles Carrots Prepacked 1Kg | 1 each
# $1.80 per 1kg
# -------------
# Coles Iceberg Lettuce | 1 each
# $1.90 per 1ea
# -------------
# Coles Shredded Iceberg Lettuce | 200g
# $10.00 per 1kg
# -------------
# Coles Mini Tomatoes | 125g
# $17.60 per 1kg
# -------------
# Coles I'M Perfect Carrots Prepacked | 1.5kg
# $1.60 per 1kg
# -------------
# Coles Baby Beetroot Prepacked | 250g
# $10.00 per 1kg
# -------------
# Fresh Garlic Cloves Prepacked | 70g
# $35.71 per 1kg
# -------------
# Coles Carrots Loose | approx. 170g each
# $2.50 per 1kg
# -------------
# Coles Green Cucumber | 1 each
# ...

# %% [markdown]
# # Fruits

# %%
# fruits URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/fruit-vegetables/fruit?sortBy=priceAscending'

# Retrieve page with the requests module
response4 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup4 = BeautifulSoup(response4.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
fruits_results = soup4.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in fruits_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Coles Lychees Loose | approx. 20g each
# $19.90 per 1kg
# -------------
# Fresh Bananas | approx. 180g each
# $2.50 per 1kg
# -------------
# Coles Yellow Nectarines | approx. 150g
# $3.40 per 1kg | Was $0.58
# -------------
# Coles White Nectarines | approx. 150g
# $3.40 per 1kg
# -------------
# Coles Packham Pears | approx. 240g
# $2.90 per 1kg
# -------------
# Coles Royal Gala Apples Loose | approx. 160g each
# $4.50 per 1kg
# -------------
# Coles Montague Tree Plums | approx. 130g
# $6.90 per 1kg | Was $1.29
# -------------
# Coles Jazz Apples | approx. 160g each
# $6.90 per 1kg
# -------------
# Coles Limes Medium Loose | 1 each
# $1.50 per 1ea
# -------------
# Coles Green Kiwifruit | 1 each
# $1.50 per 1ea
# -------------
# Coles Passionfruit | 1 each
# $1.80 per 1ea
# -------------
# Coles Medium Lemons | 1 each
# $1.80 per 1ea
# -------------
# Coles Panama Passionfruit | 1 each
# $1.80 per 1ea
# -------------
# Coles Blueberries Prepacked | 125g
# ...

# %% [markdown]
# # Coffee

# %%
# Cofee URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/pantry/coffee?sortBy=priceAscending'

# Retrieve page with the requests module
response5 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup5 = BeautifulSoup(response5.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
cofee_results = soup5.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in cofee_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Harris Coffee Filter Papers 10-12 Cup Size 4 | 1 pack
# $0.08 per 1ea
# -------------
# Coles Caramel Latte All In One Sachets 170g | 10 Pack
# $0.33 per 1ea
# -------------
# Daley Street Dark Aluminium Nespresso Compatible Coffee Capsules | 10 pack
# $0.33 per 1ea
# -------------
# Daley Street Intense Aluminium Nespresso Compatible Coffee Capsules | 10 pack
# $0.33 per 1ea
# -------------
# Coles Vanilla Latte Sachets 185g | 10 pack
# $0.33 per 1ea
# -------------
# Coles  Caramel Mocha Sachets 180g | 10 pack
# $0.33 per 1ea
# -------------
# Daley Street Dark/Intense Aluminium Nespresso Compatible Coffee Capsules | 10 pack
# $0.33 per 1ea
# -------------
# Daley Street Intese / Extreme Aluminium Nespresso Compatible Coffee Capsules | 10 pack
# $0.33 per 1ea
# -------------
# Coles Coffee Cappuccino 132g | 10 Pack
# $0.33 per 1ea
# -------------
# Coles Coffee Mocha 180g | 10 Pack
# $0.33 per 1ea
# -------------
# ...

# %% [markdown]
# # Canned (Fish & Seafood)

# %%
# Cofee URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/pantry/canned-food-soups-noodles/fish-seafood?sortBy=priceAscending'

# Retrieve page with the requests module
response6 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup6 = BeautifulSoup(response6.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
Canned_seafood_results = soup6.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in Canned_seafood_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Seacrown Sardines In Tomato Sauce | 125g
# $6.80 per 1kg
# -------------
# Seacrown Sardines In Vegetable Oil | 125g
# $6.80 per 1kg
# -------------
# Coles Mexican Style Tuna | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna Sweet Chilli | 95g
# $0.95 per 100g
# -------------
# Coles Smoke Flavour Tuna | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna With Lemon And Pepper | 95g
# $9.47 per 1kg
# -------------
# Coles Sweetcorn & Mayonnaise Tuna | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna Zesty Vinaigrette | 95g
# $0.95 per 100g
# -------------
# Coles Tuna Sweet Seeded Mustard | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna Mild Indian Curry | 95g
# $9.47 per 1kg
# -------------
# Coles Spicy Chilli Tuna | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna Onion & Savoury Sauce | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna Tomato & Basil | 95g
# $9.47 per 1kg
# -------------
# Coles Tuna Chunks in Springwater | 95g
# $9.47 per 1kg
# -------------
# ...

# %% [markdown]
# # Oil

# %%
# Cofee URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/pantry/oils-vinegars/oil?sortBy=priceAscending'

# Retrieve page with the requests module
response7 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup7= BeautifulSoup(response7.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
oil_results = soup7.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in oil_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Coles Extra Virgin Olive Oil Spray | 150g
# $1.43 per 100g
# -------------
# Coles Canola Oil Cooking Spray | 400g
# $0.63 per 100g
# -------------
# Coles Refined Olive Oil | 500mL
# $0.60 per 100mL
# -------------
# Changs Pure Sesame Oil | 150mL
# $2.20 per 100mL | Was $4.00
# -------------
# Prochef Canola Oil Spray | 400g
# $0.83 per 100g
# -------------
# Coles Rice Bran Oil | 500mL
# $0.70 per 100mL
# -------------
# Coles Organic Unrefined Extra Virgin Coconut Oil | 250g
# $1.46 per 100g
# -------------
# Coles Vegetable Oil Blended | 750mL
# $0.53 per 100mL
# -------------
# Coles Canola Oil | 750mL
# $0.53 per 100mL
# -------------
# Coco Earth Avocado Oil Spray | 150mL
# $3.00 per 100mL | Was $6.50
# -------------
# Prochef Oil Spray Extra Virgin | 260g
# $1.73 per 100g
# -------------
# Red Island Extra Virgin Olive Oil | 500mL
# $0.95 per 100mL | Was $9.50
# -------------
# La Espanola Truffle Extra Virgin Olive Oil | 250mL
# $2.00 per 100mL | Was $7.00
# ...

# %% [markdown]
# # Chocolate Blocks

# %%
# Cofee URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/pantry/confectionery/chocolate-blocks?sortBy=priceAscending'

# Retrieve page with the requests module
response8 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup8= BeautifulSoup(response8.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
Choclate_results = soup8.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in Choclate_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Green & Black's Organic 85% Dark Chocolate Block | 90g
# $2.50 per 100g | Was $4.50
# -------------
# Green & Black's Organic 70% Dark Chocolate Block | 90g
# $2.50 per 100g | Was $4.50
# -------------
# Green & Black's Organic Milk Chocolate Block | 90g
# $2.50 per 100g | Was $4.50
# -------------
# Green & Blacks Organic Milk Sea Salt Block Chocolate | 90g
# $2.50 per 100g | Was $4.50
# -------------
# Coles Belgian Milk Chocolate Block | 200g
# $1.15 per 100g
# -------------
# Coles Belgian White Chocolate Block | 200g
# $1.15 per 100g
# -------------
# Coles Belgian Dark Chocolate Block | 200g
# $1.15 per 100g
# -------------
# Coles Finest Belgian Block Dark 70% | 100g
# $2.50 per 100g
# -------------
# Coles Finest Belgian Block Dark 85% | 100g
# $2.50 per 100g
# -------------
# Coles Finest Dark Almond Belgian Block | 100g
# $2.50 per 100g
# -------------
# Libeert Dark Chocolate With Cherry & Coconut Block | 100g
# $2.50 per 100g
# -------------
# ...

# %% [markdown]
# # Baby Food

# %%
# Cofee URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/baby/baby-toddler-food?sortBy=priceAscending'

# Retrieve page with the requests module
response9 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup9= BeautifulSoup(response9.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
BabyFood_results = soup9.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in BabyFood_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Only Organic Cheese & Quinoa Green Pea Sticks 10M+ | 12g
# $7.50 per 100g | Was $1.90
# -------------
# Only Organic Berry & Banana Quinoa Hearts With Prebiotics 10M+ | 12g
# $7.50 per 100g | Was $1.90
# -------------
# Heinz Pureed Fruity Apples 4+ Months Glass Jar | 110g
# $0.91 per 100g
# -------------
# Heinz Pureed Fruity Pears 4+ Months Glass Jar | 110g
# $0.91 per 100g
# -------------
# Coles Apple Pear And Banana 6+ Months | 120g
# $0.83 per 100g
# -------------
# Coles Banana Porridge 6+ Months | 120g
# $0.83 per 100g
# -------------
# Coles Vanilla Custard 6+ Months | 120g
# $0.83 per 100g
# -------------
# Coles Beef With Vegetables 6+ Months | 120g
# $0.83 per 100g
# -------------
# Coles Chicken With Vegetables 6+ Months | 120g
# $0.83 per 100g
# -------------
# Kiddylicious Raspberry Crispie Tiddlers 12+ Months | 12g
# $10.83 per 100g | Was $2.00
# -------------
# Kiddylicious Strawberry Fruit Wriggles 12+ Months | 12g
# $10.83 per 100g | Was $2.00
# ...

# %% [markdown]
# # Vitamins & Supplements

# %%
# Cofee URL of page to be scraped (Ascending order price)
url = 'https://www.coles.com.au/browse/health-beauty/vitamins-supplements?sortBy=priceAscending'

# Retrieve page with the requests module
response10 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup10= BeautifulSoup(response10.text, 'lxml')

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
Vitamins_results = soup10.find_all('div', class_='product__message-title_area')

# Loop through returned results
for result in Vitamins_results:
    # Error handling
    try:
        title = result.find('a', class_='product__link').text
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        price = result.find('span', class_='price__calculation_method').text
        if(title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
            

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
# Sanofi Calamine Lotion - Itchiness Relief | 200mL
# $2.40 per 100mL
# -------------
# Cenovis Mega Vitamin C 1000mg Tablets For Immunity | 60 pack
# $0.09 per 1ea | Was $10.75
# -------------
# Voost Effervescent Iron Plus Tablets | 10 pack
# $55.00 per 100ea
# -------------
# Coles Effervescent Tablets Orange | 15 pack
# $0.37 per 1ea
# -------------
# Cenovis Vitamin C 250mg Tablets For Immune Support | 150 pack
# $0.04 per 1ea | Was $11.50
# -------------
# Nature's Own Folic Acid 500mg Tablets | 120 pack
# $0.05 per 1ea | Was $12.00
# -------------
# Cenovis Garlic Capsules For Immune Support | 60 pack
# $0.10 per 1ea | Was $10.30
# -------------
# Nature's Own Iron Plus Tablets | 50 pack
# $0.13 per 1ea | Was $12.50
# -------------
# Nature's Own Vitamin B3 500mg Vitamin B Tablets For Energy | 60 pack
# $10.75 per 100ea | Was $12.90
# -------------
# Cenovis Sugarless Vitamin C 500mg Tablets For Immunity | 160 pack
# $0.04 per 1ea | Was $12.95
# -------------
# ...

# %%
supermarkets = db.smitems.find({}, {'_id': False})
print(supermarkets)

# %%
# # store data into Js object


# import json
# from bson import json_util
# import os 
# txtfile_csvpath=os.path.join( 'SuperMarket_data.js')
# with open(txtfile_csvpath, "w") as txt_file: 
#     txt_file.write("let data=[")
#     for doc in supermarkets:
#         json.dump(doc, txt_file)
#         txt_file.write(",")
#     txt_file.write("]")
# #         json_docs.append(json_doc)
# # json_docs = []

# %%
# print(json_docs)

# %%
import pandas as pd

# %%
df = "colesitems.csv"
