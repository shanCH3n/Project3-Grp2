# %% [markdown]
# ## Aldi Supermarkets
# ### cofee

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialise PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.Aldi_db
collection = db.items

# %%
# URL of page to be scraped
url = 'https://www.aldi.com.au/en/groceries/fresh-produce/dairy-eggs/'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
response
# Out:
# <Response [200]>

# %%
results = soup.find_all('div',class_="ratio-container m-ratio-57x25 box--description m-no-ratio-on-phone")

# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('div',class_="box--description--header").text
        # Identify and return price of listing
        price = result.find('span', class_='box--baseprice').text
        # Identify and return link to listing
#         link = result.a['href']

        # Run only if title, price, and link are available
        if (title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
#             print(link)

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
#                 'url': link
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
#
# 					Inner Goodness Soy Milk 1L
#
# $1.99 per litre
# -------------
#
# 					Inner Goodness Almond Milk 1L
#
# $2.69 per litre
# -------------
#
# 					Farmdale Organic Full Cream Milk 1L
#
# $2.39 per litre
# -------------
#
# 					Farmdale Organic Light Milk 1L
#
# $2.39 per litre
# -------------
#
# 					Farmdale Full Cream Milk UHT 1L
#
# $1.59 per litre
# -------------
#
# 					Farmdale Light Milk UHT 1L
#
# $1.59 per litre
# -------------
#
# 					Farmdale Skim Milk UHT 1L
#
# $1.59 per litre
# -------------
#
# 					Farmdale Full Cream Milk UHT 2L
#
# $1.55 per litre
# -------------
#
# 					Farmdale Skim Milk UHT 2L
#
# $1.55 per litre
# -------------
#
# 					Farmdale Lactose Free UHT Milk 1L
#
# $1.79 per litre
# -------------
#
# 					Farmdale Lactose Free Low Fat UHT Milk 1L
#
# $1.59 per litre
# -------------
#
# 					Farmdale Lactose Free Full Cream Milk 1L
#
# $2.69 per litre
# -------------
#
# 					CHAMP Iced Coffee Flavoured Milk 2L
#
# ...

# %%
# URL of page to be scraped
url = 'https://www.aldi.com.au/en/groceries/super-savers/'

# Retrieve page with the requests module
response2 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup2 = BeautifulSoup(response2.text, 'lxml')

# %%
supersavers_results = soup2.find_all('div',class_="ratio-container m-ratio-57x25 box--description m-no-ratio-on-phone")

# Loop through returned results
for result in supersavers_results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('div',class_="box--description--header").text
        # Identify and return price of listing
        price = result.find('span', class_='box--baseprice').text
        # Identify and return link to listing
#         link = result.a['href']

        # Run only if title, price, and link are available
        if (title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
#             print(link)

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
#                 'url': link
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
# -------------
#
# 					Rocco's Butchery Bacon & Cheese Sausages 450g
#
# $13.31 per kg
# -------------
#
# 					Ready, Set…Cook! Free Range Marinated Chicken Breast Kebabs 5pk/400g
#
# $19.98 per kg
# -------------
#
# 					Luv-A-Duck Fresh Whole Duck 2kg
#
# $9.00 per kg
# -------------
#
# 					Jindurra Station Beef Round Steak per kg
#
# $17.99 per kg
# -------------
#
# 					The Fishmonger Smoked Salmon 200g
#
# $44.95 per kg
# -------------
#
# 					Killarnee Lamb Loin Chops per kg
#
# $21.99 per kg
# -------------
#
# 					Earth Grown Chickpea, Spinach & Caramelised Onion Rolls 12pk/450g
#
# $1.11 per 100g
# -------------
#
# 					Kenny’s Frozen Dessert 475ml
#
# $1.26 per 100ml
# -------------
#
# 					Market Fare Frozen Bakes 800g
#
# $7.49 per kg
# -------------
#
# 					Urban Eats Pork Dumplings or Vegetable Gyoza 750g
#
# $1.07 per 100g
# -------------
#
# 					Urban Eats Dumplings Family Pack 20pk/625g
#
# $1.92 per 100g
# -------------
#
# ...

# %%
# URL of page to be scraped
url = 'https://www.aldi.com.au/en/groceries/fresh-produce/fruit-veg/'

# Retrieve page with the requests module
response3 = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup3 = BeautifulSoup(response3.text, 'lxml')

# %%
fruitVeggie_results = soup3.find_all('div',class_="ratio-container m-ratio-57x25 box--description m-no-ratio-on-phone")

# Loop through returned results
for result in fruitVeggie_results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('div',class_="box--description--header").text
        # Identify and return price of listing
        price = result.find('span', class_='box--baseprice').text
        # Identify and return link to listing
#         link = result.a['href']

        # Run only if title, price, and link are available
        if (title and price):
            # Print results
            print('-------------')
            print(title)
            print(price)
#             print(link)

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
#                 'url': link
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)

# %%
print(fruitVeggie_results)
# Out:
# []

# %%
results = soup.find_all('div',class_="relative")

# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
#         title = result.find('a', class_='title').text
        # Identify and return price of listing
        price = result.find('span', class_=('line-clamp-3 truncate')
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        link = result.find('span', class_='capsize')

        # Run only if title, price, and link are available
        if(price and link):
            # Print results
            print('-------------')
#             print(title)
            print(price)
            print(link)

            # Dictionary to be inserted as a MongoDB document
            post = {
#                 'title': title,
                'price': price,
                'url': link
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)
# Out:
#   File "C:\Users\khans\AppData\Local\Temp\ipykernel_9468\2083377683.py", line 12
#     link = result.find('span', class_='capsize')
#        ^
# SyntaxError: invalid syntax

# %%
print(results)

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
results = soup.find_all('div', class_='flex h-full w-full flex-col justify-between')

# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
#         title = result.find('span', class_='line-clamp-3 truncate')
        # Identify and return price of listing
        price = result.find('div', class_='flex flex-col [&amp;:hover_a]:text-primary [&amp;:hover_a]:underline [&amp;>*]:block] gap-1 leading-tigh')
        # Identify and return link to listing. Square bracket notation to access attributes of an element
        link = result.find('span', class_='capsize')

        # Run only if title, price, and link are available
        if( price and link):
            # Print results
            print('-------------')
#             print(title)
            print(price)
            print(link)

            # Dictionary to be inserted as a MongoDB document
            post = {
#                 'title': title,
                'price': price,
                'url': link
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)

# %%
print(price)
